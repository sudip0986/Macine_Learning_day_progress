# %%
class MyLrClass:
    def __init__(self):
        self.m = None
        self.b = None

    def fit(self, X_train, y_train):
        num =0
        d=0
        for i in range(X_train.shape[0]):
            num += (X_train.iloc[i] - X_train.mean()) * (y_train.iloc[i] - y_train.mean())
            d += (X_train.iloc[i] - X_train.mean()) ** 2

        
        self.m=num/d
        self.b=y_train.mean() - self.m*X_train.mean()
        print(f'slope is :{self.m}')
        print(f'intercept value is :{self.b}')

    def predict(self, X_test):
        return self.m*X_test+self.b

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("placement (1).csv")
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
import matplotlib.pyplot as plt

plt.scatter(df['cgpa'], df['package'])

# %%
X=df["cgpa"]
y=df['package']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split ( X,y,test_size=0.2, random_state=2)

# %%
X_train.shape
# Out:
# (160,)

# %%
X_test.head()
# Out:
# 112    8.58
# 29     7.15
# 182    5.88
# 199    6.22
# 193    4.57
# Name: cgpa, dtype: float64

# %%
y_test.head()
# Out:
# 112    4.10
# 29     3.49
# 182    2.08
# 199    2.33
# 193    1.94
# Name: package, dtype: float64

# %%
lr = MyLrClass()

lr.fit(X_train, y_train)
# Out:
# slope is :0.5579519734250721
# intercept value is :-0.8961119222429152

# %%
lr.predict(X_test.iloc[2])
# Out:
# np.float64(2.3846456814965085)

# %%
lr.m
# Out:
# np.float64(0.5579519734250721)

# %%
X_train.head()
# Out:
# 137    7.14
# 163    8.93
# 111    5.42
# 123    5.10
# 109    7.77
# Name: cgpa, dtype: float64

# %%
import matplotlib.pyplot as plt

# scatter plot of actual data
plt.scatter(X_train, y_train)

# best fit line
y= lr.m * X_train+ lr.b
plt.plot(X_train, y , color = 'red')

plt.xlabel("X")
plt.ylabel("Y")
plt.show()
